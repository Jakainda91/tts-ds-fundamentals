# %% [markdown]
# Data Science Fundamentals: R |
# [Table of Contents](../index.ipynb)
# - - -
# <!--NAVIGATION-->
# Module 13. [Introduction](./00.ipynb) | [Basic Syntax](./01.ipynb)  | [Data Types](./02.ipynb) | [Variables](./03.ipynb) | [Operators](./04.ipynb) | [Decision Making](./05.ipynb)  | [Functions](./06.ipynb) | [Strings](./07.ipynb) | [Vectors](./08.ipynb) | [Lists](./09.ipynb) | [Matrices](./10.ipynb) | [Arrays](./11.ipynb) | [Factors](./12.ipynb) | [Data Frames](./13.ipynb) | [Data Reshaping](./14.ipynb) | [Exercises](./15.ipynb)

# %% [markdown]
# # Introduction of R

# %% [markdown]
# ![slide1](images/slide1.png)

# %% [markdown]
# ![image](images/slide2.png)

# %% [markdown]
# ![images](images/slide3.png)

# %% [markdown]
# ![image](images/slide4.png)

# %% [markdown]
# ![image](images/slide5.png)

# %% [markdown]
# # Installation of R

# %% [markdown]
# ## Starting R

# %%
When using Mac OS, submit the following from any terminal session -

# %% [raw]
# open -a /Applications/R.app

# %% [markdown]
# ## Packages

# %% [markdown]
# R packages are a collection of R functions, complied code and sample data. They are stored under a directory called "library" in the R environment. By default, R installs a set of packages during installation. More packages are added later, when they are needed for some specific purpose. When we start the R console, only the default packages are available by default. Other packages which are already installed have to be loaded explicitly to be used by the R program that is going to use them.
#
# All the packages available in R language are listed at R Packages.
#
# ![packages](images/slide6.png)
#
# Below is a list of commands to be used to check, verify and use the R packages.

# %%
installed.packages()
# Out:
#             Package     LibPath                                 Version
# askpass     askpass     /usr/local/lib/R/4.0/site-library       1.1
# assertthat  assertthat  /usr/local/lib/R/4.0/site-library       0.2.1
# backports   backports   /usr/local/lib/R/4.0/site-library       1.1.7
# base64enc   base64enc   /usr/local/lib/R/4.0/site-library       0.1-3
# BH          BH          /usr/local/lib/R/4.0/site-library       1.72.0-3
# blob        blob        /usr/local/lib/R/4.0/site-library       1.2.1
# brew        brew        /usr/local/lib/R/4.0/site-library       1.0-6
# broom       broom       /usr/local/lib/R/4.0/site-library       0.7.0
# callr       callr       /usr/local/lib/R/4.0/site-library       3.5.1
# cellranger  cellranger  /usr/local/lib/R/4.0/site-library       1.1.0
# cli         cli         /usr/local/lib/R/4.0/site-library       2.2.0
# clipr       clipr       /usr/local/lib/R/4.0/site-library       0.7.0
# colorspace  colorspace  /usr/local/lib/R/4.0/site-library       1.4-1
# commonmark  commonmark  /usr/local/lib/R/4.0/site-library       1.7
# covr        covr        /usr/local/lib/R/4.0/site-library       3.5.1
# crayon      crayon      /usr/local/lib/R/4.0/site-library       1.3.4
# credentials credentials /usr/local/lib/R/4.0/site-library       1.3.0
# crosstalk   crosstalk   /usr/local/lib/R/4.0/site-library       1.1.0.1
# curl        curl        /usr/local/lib/R/4.0/site-library       4.3
# DBI         DBI         /usr/local/lib/R/4.0/site-library       1.1.0
# dbplyr      dbplyr      /usr/local/lib/R/4.0/site-library       1.4.4
# desc        desc        /usr/local/lib/R/4.0/site-library       1.2.0
# devtools    devtools    /usr/local/lib/R/4.0/site-library       2.3.2
# DiagrammeR  DiagrammeR  /usr/local/lib/R/4.0/site-library       1.0.6.1
# digest      digest      /usr/local/lib/R/4.0/site-library       0.6.27
# downloader  downloader  /usr/local/lib/R/4.0/site-library       0.4
# dplyr       dplyr       /usr/local/lib/R/4.0/site-library       1.0.2
# DT          DT          /usr/local/lib/R/4.0/site-library       0.15
# ellipsis    ellipsis    /usr/local/lib/R/4.0/site-library       0.3.1
# evaluate    evaluate    /usr/local/lib/R/4.0/site-library       0.14
# ⋮           ⋮           ⋮                                       ⋮
# zip         zip         /usr/local/lib/R/4.0/site-library       2.1.1
# base        base        /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# boot        boot        /usr/local/Cellar/r/4.0.4/lib/R/library 1.3-26
# class       class       /usr/local/Cellar/r/4.0.4/lib/R/library 7.3-18
# cluster     cluster     /usr/local/Cellar/r/4.0.4/lib/R/library 2.1.0
# codetools   codetools   /usr/local/Cellar/r/4.0.4/lib/R/library 0.2-18
# compiler    compiler    /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# datasets    datasets    /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# foreign     foreign     /usr/local/Cellar/r/4.0.4/lib/R/library 0.8-81
# graphics    graphics    /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# grDevices   grDevices   /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# grid        grid        /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# KernSmooth  KernSmooth  /usr/local/Cellar/r/4.0.4/lib/R/library 2.23-18
# lattice     lattice     /usr/local/Cellar/r/4.0.4/lib/R/library 0.20-41
# MASS        MASS        /usr/local/Cellar/r/4.0.4/lib/R/library 7.3-53
# Matrix      Matrix      /usr/local/Cellar/r/4.0.4/lib/R/library 1.3-2
# methods     methods     /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# mgcv        mgcv        /usr/local/Cellar/r/4.0.4/lib/R/library 1.8-33
# nlme        nlme        /usr/local/Cellar/r/4.0.4/lib/R/library 3.1-152
# nnet        nnet        /usr/local/Cellar/r/4.0.4/lib/R/library 7.3-15
# parallel    parallel    /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# rpart       rpart       /usr/local/Cellar/r/4.0.4/lib/R/library 4.1-15
# spatial     spatial     /usr/local/Cellar/r/4.0.4/lib/R/library 7.3-13
# splines     splines     /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# stats       stats       /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# stats4      stats4      /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# survival    survival    /usr/local/Cellar/r/4.0.4/lib/R/library 3.2-7
# tcltk       tcltk       /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# tools       tools       /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
# utils       utils       /usr/local/Cellar/r/4.0.4/lib/R/library 4.0.4
#             Priority    Depends
# askpass     NA          NA
# assertthat  NA          NA
# backports   NA          R (>= 3.0.0)
# base64enc   NA          R (>= 2.9.0)
# BH          NA          NA
# blob        NA          NA
# brew        NA          NA
# broom       NA          R (>= 3.1)
# callr       NA          NA
# cellranger  NA          R (>= 3.0.0)
# cli         NA          R (>= 2.10)
# clipr       NA          NA
# colorspace  NA          R (>= 3.0.0), methods
# commonmark  NA          NA
# covr        NA          R (>= 3.1.0), methods
# crayon      NA          NA
# credentials NA          NA
# crosstalk   NA          NA
# curl        NA          R (>= 3.0.0)
# DBI         NA          methods, R (>= 3.0.0)
# dbplyr      NA          R (>= 3.1)
# desc        NA          R (>= 3.1.0)
# devtools    NA          R (>= 3.0.2), usethis (>= 1.6.3)
# DiagrammeR  NA          R (>= 3.2.0)
# digest      NA          R (>= 3.3.0)
# downloader  NA          NA
# dplyr       NA          R (>= 3.2.0)
# DT          NA          NA
# ellipsis    NA          R (>= 3.2)
# evaluate    NA          R (>= 3.0.2)
# ⋮           ⋮           ⋮
# zip         NA          NA
# base        base        NA
# boot        recommended R (>= 3.0.0), graphics, stats
# class       recommended R (>= 3.0.0), stats, utils
# cluster     recommended R (>= 3.3.0)
# codetools   recommended R (>= 2.1)
# compiler    base        NA
# datasets    base        NA
# foreign     recommended R (>= 4.0.0)
# graphics    base        NA
# grDevices   base        NA
# grid        base        NA
# KernSmooth  recommended R (>= 2.5.0), stats
# lattice     recommended R (>= 3.0.0)
# MASS        recommended R (>= 3.1.0), grDevices, graphics, stats, utils
# Matrix      recommended R (>= 3.6.0)
# methods     base        NA
# mgcv        recommended R (>= 2.14.0), nlme (>= 3.1-64)
# nlme        recommended R (>= 3.4.0)
# nnet        recommended R (>= 3.0.0), stats, utils
# parallel    base        NA
# rpart       recommended R (>= 2.15.0), graphics, stats, grDevices
# spatial     recommended R (>= 3.0.0), graphics, stats, utils
# splines     base        NA
# stats       base        NA
# stats4      base        NA
# survival    recommended R (>= 3.4.0)
# tcltk       base        NA
# tools       base        NA
# utils       base        NA
#             Imports
# askpass     sys (>= 2.1)
# assertthat  tools
# backports   utils
# base64enc   NA
# BH          NA
# blob        methods, rlang, vctrs (>= 0.2.1)
# brew        NA
# broom       backports, dplyr, ellipsis, generics (>= 0.0.2), glue,\nmethods, purrr, rlang, stringr, tibble (>= 3.0.0), tidyr
# callr       processx (>= 3.4.4), R6, utils
# cellranger  rematch, tibble
# cli         assertthat, crayon (>= 1.3.4), glue, methods, utils, fansi
# clipr       utils
# colorspace  graphics, grDevices, stats
# commonmark  NA
# covr        digest, stats, utils, jsonlite, rex, httr, crayon, withr (>=\n1.0.2), yaml
# crayon      grDevices, methods, utils
# credentials openssl (>= 1.3), sys (>= 2.1), curl, jsonlite, askpass
# crosstalk   htmltools (>= 0.3.6), jsonlite, lazyeval, R6
# curl        NA
# DBI         NA
# dbplyr      assertthat (>= 0.2.0), DBI (>= 1.0.0), dplyr (>= 0.8.0), glue\n(>= 1.2.0), lifecycle, magrittr, methods, purrr (>= 0.2.5), R6\n(>= 2.2.2), rlang (>= 0.2.0), tibble (>= 1.4.2), tidyselect (>=\n0.2.4), blob (>= 1.2.0), utils
# desc        assertthat, utils, R6, crayon, rprojroot
# devtools    callr (>= 3.4.4), cli (>= 2.0.2), covr (>= 3.5.1), desc (>=\n1.2.0), DT (>= 0.15), ellipsis (>= 0.3.1), httr (>= 1.4.2),\njsonlite (>= 1.7.1), memoise (>= 1.1.0), pkgbuild (>= 1.1.0),\npkgload (>= 1.1.0), rcmdcheck (>= 1.3.3), remotes (>= 2.2.0),\nrlang (>= 0.4.7), roxygen2 (>= 7.1.1), rstudioapi (>= 0.11),\nrversions (>= 2.0.2), sessioninfo (>= 1.1.1), stats, testthat\n(>= 2.3.2), tools, utils, withr (>= 2.2.0)
# DiagrammeR  dplyr (>= 0.7.6), downloader (>= 0.4), glue (>= 1.3.0),\nhtmltools (>= 0.3.6), htmlwidgets (>= 1.2), igraph (>= 1.2.2),\ninfluenceR (>= 0.1.0), magrittr (>= 1.5), purrr (>= 0.2.5),\nRColorBrewer (>= 1.1-2), readr (>= 1.1.1), rlang (>= 0.2.2),\nrstudioapi (>= 0.7), scales (>= 1.0.0), stringr (>= 1.3.1),\ntibble (>= 1.4.2), tidyr (>= 0.8.1), viridis (>= 0.5.1),\nvisNetwork (>= 2.0.4)
# digest      utils
# downloader  utils, digest
# dplyr       ellipsis, generics, glue (>= 1.3.2), lifecycle (>= 0.2.0),\nmagrittr (>= 1.5), methods, R6, rlang (>= 0.4.7), tibble (>=\n2.1.3), tidyselect (>= 1.1.0), utils, vctrs (>= 0.3.2)
# DT          htmltools (>= 0.3.6), htmlwidgets (>= 1.3), jsonlite (>=\n0.9.16), magrittr, crosstalk, promises
# ellipsis    rlang (>= 0.3.0)
# evaluate    methods
# ⋮           ⋮
# zip         NA
# base        NA
# boot        NA
# class       MASS
# cluster     graphics, grDevices, stats, utils
# codetools   NA
# compiler    NA
# datasets    NA
# foreign     methods, utils, stats
# graphics    grDevices
# grDevices   NA
# grid        grDevices, utils
# KernSmooth  NA
# lattice     grid, grDevices, graphics, stats, utils
# MASS        methods
# Matrix      methods, graphics, grid, stats, utils, lattice
# methods     utils, stats
# mgcv        methods, stats, graphics, Matrix, splines, utils
# nlme        graphics, stats, utils, lattice
# nnet        NA
# parallel    tools, compiler
# rpart       NA
# spatial     NA
# splines     graphics, stats
# stats       utils, grDevices, graphics
# stats4      graphics, methods, stats
# survival    graphics, Matrix, methods, splines, stats, utils
# tcltk       utils
# tools       NA
# utils       NA
#             LinkingTo
# askpass     NA
# assertthat  NA
# backports   NA
# base64enc   NA
# BH          NA
# blob        NA
# brew        NA
# broom       NA
# callr       NA
# cellranger  NA
# cli         NA
# clipr       NA
# colorspace  NA
# commonmark  NA
# covr        NA
# crayon      NA
# credentials NA
# crosstalk   NA
# curl        NA
# DBI         NA
# dbplyr      NA
# desc        NA
# devtools    NA
# DiagrammeR  NA
# digest      NA
# downloader  NA
# dplyr       NA
# DT          NA
# ellipsis    NA
# evaluate    NA
# ⋮           ⋮
# zip         NA
# base        NA
# boot        NA
# class       NA
# cluster     NA
# codetools   NA
# compiler    NA
# datasets    NA
# foreign     NA
# graphics    NA
# grDevices   NA
# grid        NA
# KernSmooth  NA
# lattice     NA
# MASS        NA
# Matrix      NA
# methods     NA
# mgcv        NA
# nlme        NA
# nnet        NA
# parallel    NA
# rpart       NA
# spatial     NA
# splines     NA
# stats       NA
# stats4      NA
# survival    NA
# tcltk       NA
# tools       NA
# utils       NA
#             Suggests
# askpass     testthat
# assertthat  testthat, covr
# backports   NA
# base64enc   NA
# BH          NA
# blob        covr, crayon, pillar (>= 1.2.1), testthat
# brew        NA
# broom       AER, akima, AUC, bbmle, betareg, biglm, binGroup, boot,\nbtergm, car, caret, cluster, coda, covr, drc, e1071, emmeans,\nepiR, ergm, fixest (>= 0.3.1), gam (>= 1.15), gamlss,\ngamlss.data, gamlss.dist, gee, geepack, ggplot2, glmnet,\nglmnetUtils, gmm, Hmisc, irlba, joineRML, Kendall, knitr, ks,\nLahman, lavaan, leaps, lfe, lm.beta, lme4, lmodel2, lmtest,\nlsmeans, maps, maptools, MASS, Matrix, mclogit, mclust,\nmediation, metafor, mfx, mgcv, modeldata, modeltests, muhaz,\nmultcomp, network, nnet, orcutt (>= 2.2), ordinal, plm, poLCA,\npsych, quantreg, rgeos, rmarkdown, robust, robustbase, rsample,\nsandwich, sp, spdep, spatialreg, speedglm, spelling,\nstatnet.common, survey, survival, systemfit, testthat (>=\n2.1.0), tseries, zoo
# callr       cli, covr, crayon, fansi, pingr, ps, rprojroot, spelling,\ntestthat, tibble, withr (>= 2.3.0)
# cellranger  covr, testthat (>= 1.0.0), knitr, rmarkdown
# cli         callr, covr, htmlwidgets, knitr, mockery, ps (>= 1.3.4.9000),\nrmarkdown, rstudioapi, prettycode (>= 1.1.0), testthat, withr
# clipr       covr, knitr, rmarkdown, rstudioapi (>= 0.5), testthat (>=\n2.0.0)
# colorspace  datasets, utils, KernSmooth, MASS, kernlab, mvtnorm, vcd,\ntcltk, shiny, shinyjs, ggplot2, dplyr, scales, grid, png, jpeg,\nknitr, rmarkdown, RColorBrewer, rcartocolor, scico, viridis,\nwesanderson
# ...
# survival    NA
# tcltk       NA
# tools       codetools, methods, xml2, curl, commonmark
# utils       methods, xml2, commonmark
#             Enhances
# askpass     NA
# assertthat  NA
# backports   NA
# base64enc   png
# BH          NA
# blob        NA
# brew        NA
# broom       NA
# callr       NA
# cellranger  NA
# cli         NA
# clipr       NA
# colorspace  NA
# commonmark  NA
# covr        NA
# crayon      NA
# credentials NA
# crosstalk   NA
# curl        NA
# DBI         NA
# dbplyr      NA
# desc        NA
# devtools    NA
# DiagrammeR  NA
# digest      NA
# downloader  NA
# dplyr       NA
# DT          NA
# ellipsis    NA
# evaluate    NA
# ⋮           ⋮
# zip         NA
# base        NA
# boot        NA
# class       NA
# cluster     NA
# codetools   NA
# compiler    NA
# datasets    NA
# foreign     NA
# graphics    NA
# grDevices   NA
# grid        NA
# KernSmooth  NA
# lattice     chron
# MASS        NA
# Matrix      MatrixModels, graph, SparseM, sfsmisc, igraph, maptools, sp,\nspdep
# methods     NA
# mgcv        NA
# nlme        NA
# nnet        NA
# parallel    snow, nws, Rmpi
# rpart       NA
# spatial     NA
# splines     NA
# stats       NA
# stats4      NA
# survival    NA
# tcltk       NA
# tools       NA
# utils       NA
#             License                     License_is_FOSS License_restricts_use
# askpass     MIT + file LICENSE          NA              NA
# assertthat  GPL-3                       NA              NA
# backports   GPL-2 | GPL-3               NA              NA
# base64enc   GPL-2 | GPL-3               NA              NA
# BH          BSL-1.0                     NA              NA
# blob        GPL-3                       NA              NA
# brew        GPL-2                       NA              NA
# broom       MIT + file LICENSE          NA              NA
# callr       MIT + file LICENSE          NA              NA
# cellranger  MIT + file LICENSE          NA              NA
# cli         MIT + file LICENSE          NA              NA
# clipr       GPL-3                       NA              NA
# colorspace  BSD_3_clause + file LICENSE NA              NA
# commonmark  BSD_2_clause + file LICENSE NA              NA
# covr        GPL-3                       NA              NA
# crayon      MIT + file LICENSE          NA              NA
# credentials MIT + file LICENSE          NA              NA
# crosstalk   MIT + file LICENSE          NA              NA
# curl        MIT + file LICENSE          NA              NA
# DBI         LGPL (>= 2.1)               NA              NA
# dbplyr      MIT + file LICENSE          NA              NA
# desc        MIT + file LICENSE          NA              NA
# devtools    GPL (>= 2)                  NA              NA
# DiagrammeR  MIT + file LICENSE          NA              NA
# digest      GPL (>= 2)                  NA              NA
# downloader  GPL-2                       NA              NA
# dplyr       MIT + file LICENSE          NA              NA
# DT          GPL-3 | file LICENSE        NA              NA
# ellipsis    GPL-3                       NA              NA
# evaluate    MIT + file LICENSE          NA              NA
# ⋮           ⋮                           ⋮               ⋮
# zip         CC0                         NA              NA
# base        Part of R 4.0.4             NA              NA
# boot        Unlimited                   NA              NA
# class       GPL-2 | GPL-3               NA              NA
# cluster     GPL (>= 2)                  NA              NA
# codetools   GPL                         NA              NA
# compiler    Part of R 4.0.4             NA              NA
# datasets    Part of R 4.0.4             NA              NA
# foreign     GPL (>= 2)                  NA              NA
# graphics    Part of R 4.0.4             NA              NA
# grDevices   Part of R 4.0.4             NA              NA
# grid        Part of R 4.0.4             NA              NA
# KernSmooth  Unlimited                   NA              NA
# lattice     GPL (>= 2)                  NA              NA
# MASS        GPL-2 | GPL-3               NA              NA
# Matrix      GPL (>= 2) | file LICENCE   NA              NA
# methods     Part of R 4.0.4             NA              NA
# mgcv        GPL (>= 2)                  NA              NA
# nlme        GPL (>= 2) | file LICENCE   NA              NA
# nnet        GPL-2 | GPL-3               NA              NA
# parallel    Part of R 4.0.4             NA              NA
# rpart       GPL-2 | GPL-3               NA              NA
# spatial     GPL-2 | GPL-3               NA              NA
# splines     Part of R 4.0.4             NA              NA
# stats       Part of R 4.0.4             NA              NA
# stats4      Part of R 4.0.4             NA              NA
# survival    LGPL (>= 2)                 NA              NA
# tcltk       Part of R 4.0.4             NA              NA
# tools       Part of R 4.0.4             NA              NA
# utils       Part of R 4.0.4             NA              NA
#             OS_type MD5sum NeedsCompilation Built
# askpass     NA      NA     yes              4.0.2
# assertthat  NA      NA     no               4.0.1
# backports   NA      NA     yes              4.0.1
# base64enc   NA      NA     yes              4.0.1
# BH          NA      NA     no               4.0.2
# blob        NA      NA     no               4.0.2
# brew        NA      NA     NA               4.0.2
# broom       NA      NA     no               4.0.2
# callr       NA      NA     no               4.0.3
# cellranger  NA      NA     no               4.0.1
# cli         NA      NA     no               4.0.3
# clipr       NA      NA     no               4.0.2
# colorspace  NA      NA     yes              4.0.2
# commonmark  NA      NA     yes              4.0.2
# covr        NA      NA     yes              4.0.3
# crayon      NA      NA     no               4.0.1
# credentials NA      NA     no               4.0.3
# crosstalk   NA      NA     no               4.0.2
# curl        NA      NA     yes              4.0.2
# DBI         NA      NA     no               4.0.2
# dbplyr      NA      NA     no               4.0.2
# desc        NA      NA     no               4.0.2
# devtools    NA      NA     no               4.0.4
# DiagrammeR  NA      NA     no               4.0.2
# digest      NA      NA     yes              4.0.3
# downloader  NA      NA     no               4.0.2
# dplyr       NA      NA     yes              4.0.3
# DT          NA      NA     no               4.0.2
# ellipsis    NA      NA     yes              4.0.1
# evaluate    NA      NA     no               4.0.1
# ⋮           ⋮       ⋮      ⋮                ⋮
# zip         NA      NA     yes              4.0.3
# base        NA      NA     NA               4.0.4
# boot        NA      NA     no               4.0.4
# class       NA      NA     yes              4.0.4
# cluster     NA      NA     yes              4.0.4
# codetools   NA      NA     no               4.0.4
# compiler    NA      NA     NA               4.0.4
# datasets    NA      NA     NA               4.0.4
# foreign     NA      NA     yes              4.0.4
# graphics    NA      NA     yes              4.0.4
# grDevices   NA      NA     yes              4.0.4
# grid        NA      NA     yes              4.0.4
# KernSmooth  NA      NA     yes              4.0.4
# lattice     NA      NA     yes              4.0.4
# MASS        NA      NA     yes              4.0.4
# Matrix      NA      NA     yes              4.0.4
# methods     NA      NA     yes              4.0.4
# mgcv        NA      NA     yes              4.0.4
# nlme        NA      NA     yes              4.0.4
# nnet        NA      NA     yes              4.0.4
# parallel    NA      NA     yes              4.0.4
# rpart       NA      NA     yes              4.0.4
# spatial     NA      NA     yes              4.0.4
# splines     NA      NA     yes              4.0.4
# stats       NA      NA     yes              4.0.4
# stats4      NA      NA     NA               4.0.4
# survival    NA      NA     yes              4.0.4
# tcltk       NA      NA     yes              4.0.4
# tools       NA      NA     yes              4.0.4
# utils       NA      NA     yes              4.0.4

# %% [markdown]
# Check Available R Packages
# ---
#
# Get library locations containing R packages

# %%
.libPaths()
# Out:
# [1] "/usr/local/lib/R/4.0/site-library"
# [2] "/usr/local/Cellar/r/4.0.4/lib/R/library"

# %% [markdown]
# Get the list of all the packages installed
# ---

# %%
library()

# %% [markdown]
# Get all packages currently loaded in the R environment
# ---

# %%
search()
# Out:
#  [1] ".GlobalEnv"        "jupyter:irkernel"  "package:stats"
#  [4] "package:graphics"  "package:grDevices" "package:utils"
#  [7] "package:datasets"  "package:methods"   "Autoloads"
# [10] "package:base"

# %% [markdown]
# Install a New Package
# ---
#
# There are two ways to add new R packages. One is installing directly from the CRAN directory and another is downloading the package to your local system and installing it manually.
#
# <b>Install Packages Directly from Cran</b>
#
# The following command gets the packages directly from CRAN webpage and installs the package in the R environment. You may be prompted to choose a nearest mirror. Choose the one appropriate to your location.

# %%
# install.packages("Package Name")

# Install the package named "XML".

install.packages("xml2")
# Out:
# Installing package into ‘/usr/local/lib/R/4.0/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("xml2"):
# “installation of package ‘xml2’ had non-zero exit status”

# %%
library("xml2")

# %% [markdown]
# <b>Install Packages Manually</b>

# %% [markdown]
# [View Packages](https://cran.r-project.org/web/packages/available_packages_by_name.html)
#
# [View Documentation](https://cran.r-project.org/doc/manuals/r-release/R-admin.html)

# %% [markdown]
# Save the package as a .zip file in a suitable location in the local system.
#
# Now you can run the following command to install this package in the R environment.

# %% [raw]
# install.packages(file_name_with_path, repos = NULL, type = "source")
#
# # Install the package named "XML"
#
# install.packages("E:/XML_3.98-1.3.zip", repos = NULL, type = "source")

# %% [markdown]
# Load Package to Library
# ---
#
# Before a package can be used in the code, it must be loaded to the current R environment. You also need to load a package that is already installed previously but not available in the current environment.
#
# A package is loaded using the following command −

# %% [raw]
# library("package Name", lib.loc = "path to library")
#
# # Load the package named "XML"
#
# install.packages("E:/XML_3.98-1.3.zip", repos = NULL, type = "source")

# %% [markdown]
# Troubleshooting
# ---
#
# When you install packages in R with Mac OS X (10.9), if you get this warning:

# %% [raw]
# tar: Failed to set default locale

# %% [markdown]
# In shell you have LANG set to en_US and LC_ALL set to en_US.UTF-8.

# %% [markdown]
# This command seems to fix it:

# %% [raw]
# defaults write org.R-project.R force.LANG en_US.UTF-8

# %% [markdown]
# ![caption](files/fix.png)

# %% [markdown]
# After restarting R, no more warnings about the default locale.

# %% [markdown]
# Most Common R Packages
# ---

# %% [markdown]
# ![caption](files/packages.jpg)

# %% [markdown]
# Submit the following code / function to install load multiple packages at once

# %% [raw]
# # ipak function: install and load multiple R packages.
# # check to see if packages are installed. Install them if they are not, then load them into the R session.
# LSMeans, Comparision, RegTest, ACD, Bison
# ipak <- function(pkg){
#     new.pkg <- pkg[!(pkg %in% installed.packages()[, "Package"])]
#     if (length(new.pkg))
#         install.packages(new.pkg, dependencies = TRUE)
#     sapply(pkg, require, character.only = TRUE)
# }
#
# # usage
# packages <- c("ggplot2", "plyr", "reshape2", "RColorBrewer", "scales", "grid")
#
# #pre-modeling stage
# #packages
#
# #modeling stage
# #packages
#
# #post modeling stage
# #packages
#
# # other libraries
# # packages <- c("rcpp", "parallel", "XML", "jasonlite", "httr", "shiny", "RMarkdown", "tm", "twitterR", "sqldf" "ROBDC", RMongo", "swirl", "reshape2", "qcc")
#
# ipak(packages)

# %% [markdown]
# ## R Programming Tutorial - Learn the Basics of Statistical Computing

# %%
library(IRdisplay)

  display_html("<iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>")
# Out:
# <iframe width='560' height='315' src='https://www.youtube.com/embed/_V8eKsto3Ug?rel=0&amp;controls=0&amp;showinfo=0'</iframe>

# %% [markdown]
# - - -
# <!--NAVIGATION-->
# Module 13. [Introduction](./00.ipynb) | [Basic Syntax](./01.ipynb)  | [Data Types](./02.ipynb) | [Variables](./03.ipynb) | [Operators](./04.ipynb) | [Decision Making](./05.ipynb)  | [Functions](./06.ipynb) | [Strings](./07.ipynb) | [Vectors](./08.ipynb) | [Lists](./09.ipynb) | [Matrices](./10.ipynb) | [Arrays](./11.ipynb) | [Factors](./12.ipynb) | [Data Frames](./13.ipynb) | [Data Reshaping](./14.ipynb) | [Exercises](./15.ipynb)
